# %% [markdown]
# # date-02/12/2025
#
# statistics

# %%
import numpy as np

x=np.array([1,2,3,1])
y=np.array([[1,2,3],[5,6,1]])
print(x.mean())
print(np.median(x))
print(np.median(y,axis=-1))#Last axis
print(x.std()) # full population standard dev

#steps for stardard deviations
#step1:mean
#step2:differrence from array elements to mean
#step 3:square of all the differrence
#step 4:sum of all the difference
# step 5: divide the sum by size of list(population variance)
#squareroot
# Out:
# 1.75
# 1.5
# [2. 5.]
# 0.82915619758885

# %%
data=np.loadtxt("populations.txt")
print(data)
# Out:
# [[ 1900. 30000.  4000. 48300.]
#  [ 1901. 47200.  6100. 48200.]
#  [ 1902. 70200.  9800. 41500.]
#  [ 1903. 77400. 35200. 38200.]
#  [ 1904. 36300. 59400. 40600.]
#  [ 1905. 20600. 41700. 39800.]
#  [ 1906. 18100. 19000. 38600.]
#  [ 1907. 21400. 13000. 42300.]
#  [ 1908. 22000.  8300. 44500.]
#  [ 1909. 25400.  9100. 42100.]
#  [ 1910. 27100.  7400. 46000.]
#  [ 1911. 40300.  8000. 46800.]
#  [ 1912. 57000. 12300. 43800.]
#  [ 1913. 76600. 19500. 40900.]
#  [ 1914. 52300. 45700. 39400.]
#  [ 1915. 19500. 51100. 39000.]
#  [ 1916. 11200. 29700. 36700.]
#  [ 1917.  7600. 15800. 41800.]
#  [ 1918. 14600.  9700. 43300.]
#  [ 1919. 16200. 10100. 41300.]
#  [ 1920. 24700.  8600. 47300.]]

# %%
year,hares,lynxes,carrots =data.T #columns to varisbles
print(year)
# Out:
# [1900. 1901. 1902. 1903. 1904. 1905. 1906. 1907. 1908. 1909. 1910. 1911.
#  1912. 1913. 1914. 1915. 1916. 1917. 1918. 1919. 1920.]

# %%
#The mean population over time
populations=data[:,1:]
populations
# Out:
# array([[30000.,  4000., 48300.],
#        [47200.,  6100., 48200.],
#        [70200.,  9800., 41500.],
#        [77400., 35200., 38200.],
#        [36300., 59400., 40600.],
#        [20600., 41700., 39800.],
#        [18100., 19000., 38600.],
#        [21400., 13000., 42300.],
#        [22000.,  8300., 44500.],
#        [25400.,  9100., 42100.],
#        [27100.,  7400., 46000.],
#        [40300.,  8000., 46800.],
#        [57000., 12300., 43800.],
#        [76600., 19500., 40900.],
#        [52300., 45700., 39400.],
#        [19500., 51100., 39000.],
#        [11200., 29700., 36700.],
#        [ 7600., 15800., 41800.],
#        [14600.,  9700., 43300.],
#        [16200., 10100., 41300.],
#        [24700.,  8600., 47300.]])

# %%
#sample standard deviations
populations.std(axis=0)
# Out:
# array([20897.90645809, 16254.59153691,  3322.50622558])

# %%
#which species has the highest population each year?
np.argmax(populations,axis=1) #har row me maximum value ka index de raha hai
# Out:
# array([2, 2, 0, 0, 1, 1, 2, 2, 2, 2, 2, 2, 0, 0, 0, 1, 2, 2, 2, 2, 2])

# %% [markdown]
# # BroadCasting

# %%
a=np.tile(np.arange(0,40,10),(3,1))
print(a)
print("**************")
a=a.T
print(a)
# Out:
# [[ 0 10 20 30]
#  [ 0 10 20 30]
#  [ 0 10 20 30]]
# **************
# [[ 0  0  0]
#  [10 10 10]
#  [20 20 20]
#  [30 30 30]]

# %%
print(a.shape) # find shape
b=np.array([0,1,2])
print(b)
a+b
# Out:
# (4, 3)
# [0 1 2]
# array([[ 0,  1,  2],
#        [10, 11, 12],
#        [20, 21, 22],
#        [30, 31, 32]])
